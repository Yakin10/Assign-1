# %%
import numpy as np
import pandas as pd
import re

# %%
def min_edit_dist(t1,t2):
    m,n = len(t1)+1,len(t2)+1
    distance_mat = np.zeros([m,n])
    for j in range(n):
        distance_mat[0][j] = j
    for i in range(m):
        distance_mat[i][0] = i
    distance_mat
    cost=0
    
    for i in range(1,m):
        for j in range(1,n):
            if(t1[i-1] == t2[j-1]):
                cost=0
            else:
                cost=1
            a = distance_mat[i-1][j]+1
            b = distance_mat[i,j-1]+1
            c = distance_mat[i-1,j-1]+cost
            distance_mat[i,j]=min(a,b,c)
    return distance_mat[m-1,n-1]

# %%
text,c = [],[]
with open("courps.txt") as r:
    for t in r.readlines():
        if(re.match(r"\A[$]",t)):
            c.append(t)
        else:
            text.append(t)

# %%
misspelled = []
spelled = []
t3 = []
count = 0
for t in text:
    t1 = re.split(r"\s+",t)
    for t2 in t1:
        if(re.match(r".\w",t2)):
            if((re.sub(r"[^a-zA-Z]","",t2)).isalpha()):
                t3.append(re.sub(r"[^a-zA-Z]","",t2))
            
for t in t3:
    count=count+1
    if(count%2 == 1):
        misspelled.append(t)
    else:
        spelled.append(t)

# %%
from nltk.corpus import words as wn

# %%
wordlist = wn.words()
f_list,sak1,sak5,sak10 = [],[],[],[]
count = 0;
try1 = {}
for w in misspelled:
    m_c = w[0]
    for w1 in wordlist:
        if(len(w1)>=len(w)-2 and len(w1)<=(len(w)+2)):
            c = w1[0]
            if(m_c == c):
                f_list.append(w1)
    q = sim_word(f_list,w)
    df = pd.DataFrame(q, columns=["MED",w])
    df = df.sort_values("MED", ignore_index=True)
    p = int(min_edit_dist(w,spelled[count]))
    qrel = {w : {spelled[count]:p}}
    run = {w : {
        df[w][9]:df["MED"][9],
        df[w][5]:df["MED"][5],
        df[w][0]:df["MED"][0],
    }}
    eva = pytrec_eval.RelevanceEvaluator(qrel,{'map','ndcg'})
    pytrec_eval.supported_measures
    print("General S@k for top 10 : ",json.dumps(eva.evaluate(run), indent=1))
    
    print((df[w][0],spelled[count]))
    
    #sak(df,count)
    count = count+1
    if(count == 20): break
    '''for i in sorted(q.keys()):
        print((i,q[i]),end=",")
    print(w)
    print("end")'''
# Out:
# General S@k for top 10 :  {
#  "caugt": {
#   "map": 0.1,
#   "ndcg": 0.2890648263178879
#  }
# }
# ('caught', 'caught')
# General S@k for top 10 :  {
#  "choped": {
#   "map": 0.14285714285714285,
#   "ndcg": 0.3333333333333333
#  }
# }
# ('chopped', 'chopped')
# General S@k for top 10 :  {
#  "senery": {
#   "map": 0.1,
#   "ndcg": 0.2890648263178879
#  }
# }
# ('sentry', 'scenery')
# General S@k for top 10 :  {
#  "tak": {
#   "map": 0.1111111111111111,
#   "ndcg": 0.3010299956639812
#  }
# }
# ('tar', 'take')
# General S@k for top 10 :  {
#  "thougt": {
#   "map": 0.16666666666666666,
#   "ndcg": 0.3562071871080222
#  }
# }
# ('thought', 'thought')
# General S@k for top 10 :  {
#  "tought": {
#   "map": 0.3333333333333333,
#   "ndcg": 0.5
#  }
# }
# ('tought', 'thought')
# General S@k for top 10 :  {
#  "tim": {
#   "map": 0.25,
#   "ndcg": 0.43067655807339306
#  }
# }
# ('tip', 'time')
# General S@k for top 10 :  {
#  "wam": {
#   "map": 0.2,
#   "ndcg": 0.38685280723454163
#  }
# }
# ('wad', 'warm')
# General S@k for top 10 :  {
#  "beatiful": {
#   "map": 0.1111111111111111,
#   "ndcg": 0.3010299956639812
#  }
# }
# ('beautiful', 'beautiful')
# General S@k for top 10 :  {
#  "beateful": {
#   "map": 0.2,
#   "ndcg": 0.38685280723454163
#  }
# }
# ('beakful', 'beautiful')
# General S@k for top 10 :  {
#  "brough": {
#   "map": 0.5,
#   "ndcg": 0.6309297535714575
#  }
# }
# ('brough', 'brought')
# General S@k for top 10 :  {
#  "carring": {
#   "map": 0.3333333333333333,
#   "ndcg": 0.5
#  }
# }
# ('carling', 'carrying')
# General S@k for top 10 :  {
#  "desing": {
#   "map": 0.0,
#   "ndcg": 0.0
#  }
# }
# ('besing', 'deciding')
# General S@k for top 10 :  {
#  "dive": {
#   "map": 0.0,
#   "ndcg": 0.0
#  }
# }
# ('dive', 'drive')
# General S@k for top 10 :  {
#  "fishs": {
#   "map": 0.0,
#   "ndcg": 0.0
#  }
# }
# ('fish', 'fishes')
# General S@k for top 10 :  {
#  "fishig": {
#   "map": 0.2,
#   "ndcg": 0.38685280723454163
#  }
# }
# ('fishing', 'fishing')
# General S@k for top 10 :  {
#  "fishin": {
#   "map": 0.14285714285714285,
#   "ndcg": 0.3333333333333333
#  }
# }
# ('fishing', 'fishing')
# General S@k for top 10 :  {
#  "mus": {
#   "map": 0.5,
#   "ndcg": 0.6309297535714575
#  }
# }
# ('mush', 'must')
# General S@k for top 10 :  {
#  "notced": {
#   "map": 0.0,
#   "ndcg": 0.0
#  }
# }
# ('notched', 'noticed')
# General S@k for top 10 :  {
#  "thaugh": {
#   "map": 0.0,
#   "ndcg": 0.0
#  }
# }
# ('though', 'thought')

# %%
def sim_word(wordlist, miss_word):
    l = len(wordlist)
    p = min_edit_dist(miss_word,wordlist[0])
    dis = []
    for i in range(1,l):
        dis_word = []
        dis_word.append(min_edit_dist(miss_word,wordlist[i]))
        dis_word.append(wordlist[i])
        dis.append(dis_word)
    return dis

# %%
def fun(q):
    print(len(q))
    for i in sorted(q.keys()):
        if(i == 1 or i ==5):
            print((i,q[i]))
        if(i == 10):
            print((i,q[i]))
            break

# %%
import pytrec_eval
import json

# %%
def sak(df,count):
    sak1.append(df["MED"][0])
    sak5.append(df["MED"][4])
    sak10.append(df["MED"][9])
    
    try1[df[w][0]] = df["MED"][0]
    try1[df[w][4]] = df["MED"][4]
    try1[df[w][9]] = df["MED"][9]


    print("\nMisspelled Word : ",w)
    print("S@K for 1",sak1[count])
    print("S@K for 5",sak5[count])
    print("S@K for 10",sak10[count])
    print("Correct word :", spelled[count])
